# %% [markdown]
# > **Data required:** This notebook uses InSight HP³ data from Spohn et al. (2024).
# > If you haven't already, download the datasets from [FigShare](https://doi.org/10.6084/m9.figshare.25099754)
# > and place them in `resources/data/`. See [`resources/data/README.md`](../resources/data/README.md) for details.

# %% [markdown]
# # 1D Heat Diffusion on Mars — Learning κ from Data (Inverse Problem)
#
# The governing equation is unchanged:
#
# $$\frac{\partial T}{\partial t} = \kappa \frac{\partial^2 T}{\partial x^2}$$
#
# Everything about the domain, the data sources, and the three loss terms is identical to the previous notebook. The difference is a single, fundamental shift in what the network is asked to do.
#
# ---
#
# ## Forward vs. Inverse — What Changed
#
# In the previous notebook, $\kappa = 3.93 \times 10^{-8}\ \text{m}^2/\text{s}$ was **fixed**. We assumed Spohn et al.'s value was correct, handed it to the physics residual, and asked the network to learn $T(x, t)$ alone.
#
# This notebook poses a different question: **what if we don't trust that number?** What if the data itself can tell us what $\kappa$ should be?
#
# This is the **inverse problem**. Instead of:
#
# $$\text{given } \kappa,\ \text{find } T(x,t)$$
#
# we now solve:
#
# $$\text{given measurements of } T,\ \text{find } \kappa \text{ and } T(x,t) \text{ simultaneously}$$
#
# The network no longer just fits a temperature field — it also *interrogates the physics* to find the diffusivity that best explains the observations.
#
# ---
#
# ## Why Learn log(κ) Instead of κ Directly?
#
# We do not add $\kappa$ as a raw trainable parameter. Instead, we learn $\log(\kappa)$ and recover the physical value as:
#
# $$\kappa = e^{\log \kappa}$$
#
# There are two reasons for this. First, $\kappa$ must be strictly positive — a negative diffusivity is physically nonsensical, and gradient descent has no awareness of this constraint. Parameterising through the exponential makes positivity automatic. Second, $\kappa \sim 10^{-8}$ is many orders of magnitude smaller than the network weights, which live near order 1. Gradient updates in raw $\kappa$ space would be numerically tiny and unstable. In log space, the optimiser works with a number of order $-17$, and updates are proportionally meaningful.
#
# ---
#
# ## Initialisation and What We Expect
#
# We initialise $\log(\kappa) = \log(3.93 \times 10^{-8})$ — Spohn's published value from the HP³ analysis. This is not a random starting point; it is an informed prior from the best available literature estimate.
#
# The network then tunes $\kappa$ alongside the weights during training, driven jointly by:
#
# - The boundary loss anchoring the surface and deep temperatures
# - The physics residual demanding the heat equation is satisfied everywhere
# - The data loss pulling the solution toward the mole's actual subsurface measurements
#
# If the model is well-posed and the data is informative, the learned $\kappa$ should converge to a value close to — or a refinement of — what Spohn found through classical wave-fitting analysis. The printed value of `current kappa` during training is one of the most meaningful diagnostics in this notebook: watching a physical constant emerge from data.
#
# ---
#
# ## A Note on the Single-Layer Assumption
#
# This notebook treats $\kappa$ as a **single scalar constant** — uniform across all depths from $0$ to $0.4\ \text{m}$ and fixed for all time. This is a deliberate simplification. Spohn et al. find evidence for thermal stratification, with the upper duricrust behaving differently from deeper regolith. A single $\kappa$ is the simplest physically meaningful model. Whether it is sufficient is something the residual errors will tell us.

# %%
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
from jax import random, grad, jit, vmap
import openpyxl
import optax

import jax.numpy as jnp

import copy

# Problem parameters
kappa = 1e-9      # thermal diffusivity [m^2/s]. Intial guess for the inverse problem (Spohn's value). We will learn this parameter.
depth = 0.4           # domain depth [m]
sol_seconds = 88775.244  # one sol [s]

avg_bottom_temp = 225.6  # average bottom temperature (K)
mole_depth = 0.094  # representative depth for diurnal signal [m]

# TEM-A Sol 1202 = mole temperature over one sol (the warmest sol sampled)
# RAD Sol 511   = surface temperature from radiometer (Spohn's proxy for sol 1202)

wb_diurnal = openpyxl.load_workbook(
    '../resources/data/Mars Soil Temperatures and Thermal Properties from Diurnal Wave data.xlsx',
    data_only=True
)

# --- Mole temperature (TEM-A Sol 1202) ---
ws_tem = wb_diurnal['TEM-A Sol 1202']
ltst_mole, temp_mole = [], []
for row in ws_tem.iter_rows(min_row=2, values_only=True):
    # Column index 6 = 'LTST Conversion step 2' (hours, 0-24)
    # Column index 7 = 'average T15, T16' (Kelvin)
    ltst_val = row[6]
    temp_val = row[7]
    if ltst_val is not None and temp_val is not None:
        try:
            t = float(ltst_val)
            T = float(temp_val)
            if 0 <= t <= 24 and 200 < T < 260:
                ltst_mole.append(t)
                temp_mole.append(T)
        except (ValueError, TypeError):
            pass


# --- Surface temperature (RAD Sol 511) ---
ws_rad = wb_diurnal['RAD SOL 511 D']
ltst_surf, temp_surf = [], []
for row in ws_rad.iter_rows(min_row=2, values_only=True):
    # Column index 4 = 'LTST converted' (hours)
    # Column index 5 = 'FOV 2 Temperature converted' (Kelvin)
    try:
        t = float(row[4])
        T = float(row[5])
        if 0 <= t <= 24 and 150 < T < 350:
            ltst_surf.append(t)
            temp_surf.append(T)
    except (ValueError, TypeError):
        pass

# Sort surface data by LTST (it may not be in order)
sorted_surf = sorted(zip(ltst_surf, temp_surf))
ltst_surf = [x[0] for x in sorted_surf]
temp_surf = [x[1] for x in sorted_surf]

# Conversion from hours to seconds for the time points. Make sure it is mapped correctly to the Mars sol time (0-88775.244 seconds)
ltst_mole = [t * sol_seconds / 24 for t in ltst_mole]
ltst_surf = [t * sol_seconds / 24 for t in ltst_surf]


# 1. Boundary Condition points (552 points each edge as we have 552 time points in the surface data)
n_surface = len(ltst_surf)  # Should be 552

# Surface boundary (x=0):
t_bc_surface = jnp.array(ltst_surf).reshape(-1, 1)  # (552, 1)
x_bc_surface = jnp.zeros((n_surface, 1))  # (552, 1)

u_bc_surface = jnp.array(temp_surf).reshape(-1, 1)  # (552, 1)

# Bottom boundary (x=depth):
t_bc_bottom = jnp.linspace(0, sol_seconds, n_surface).reshape(-1, 1)  # (552, 1)
x_bc_bottom = jnp.ones((n_surface, 1)) * depth

u_bc_bottom = jnp.ones((n_surface, 1)) * avg_bottom_temp  # (552, 1)

# Combine them:
t_bc = jnp.concatenate([t_bc_surface, t_bc_bottom])
x_bc = jnp.concatenate([x_bc_surface, x_bc_bottom])
u_bc = jnp.concatenate([u_bc_surface, u_bc_bottom])


# 2. Physics collocation points (100 * 100 = 10,000 points)
key = random.PRNGKey(0)
key1, key2 = random.split(key)
t_physics = random.uniform(key1, (10000, 1), minval=0, maxval=sol_seconds)
x_physics = random.uniform(key2, (10000, 1), minval=0, maxval=depth)


# 3. Data points for Data Loss (5550 points)
# We can use the mole temperature data as additional data points inside the domain (not just at the boundaries). This will help guide the network to learn the correct solution.

t_data = jnp.array(ltst_mole).reshape(-1, 1)
x_data = jnp.ones((len(ltst_mole), 1)) * mole_depth
u_data = jnp.array(temp_mole).reshape(-1, 1)


# Normalise the data so the network only sees values of order 1. This helps with training stability and convergence. We will need to un-normalise the predictions later to compare with the original data.

# Normalisation parameters
t_min, t_max = 0.0, sol_seconds
x_min, x_max = 0.0, depth
u_min, u_max = 185.0, 300.0  # Based on the range of temperatures in the data

def normalize_t(t): return ( t - t_min) / (t_max - t_min)
def normalize_x(x): return ( x - x_min) / (x_max - x_min)
def normalize_u(u): return ( u - u_min) / (u_max - u_min)

def unnormalize_u(u_norm): return u_norm * (u_max - u_min) + u_min

# Normalize all data
t_bc = normalize_t(t_bc)
x_bc = normalize_x(x_bc)
u_bc = normalize_u(u_bc)

t_physics = normalize_t(t_physics)
x_physics = normalize_x(x_physics)

t_data = normalize_t(t_data)
x_data = normalize_x(x_data)
u_data = normalize_u(u_data)

#Normalize kappa as well (since it appears in the physics residual)
def normalize_kappa(kappa):
    return kappa * (t_max - t_min) / ((x_max - x_min)**2)

# Neural Network

def init_network_params(layer_sizes, key):
    """
    Initialize parameters for a fully connected network.
    
    Args:
        layer_sizes: List of layer sizes, e.g., [2, 32, 32, 32, 1]
                    (input_dim, hidden1, hidden2, hidden3, output_dim)
        key: JAX random key for initialization
        
    Returns:
        params: idctionary containging the network list of dictionaries and log_kappa
    """
    # Split random key for each layer
    keys = random.split(key, len(layer_sizes))

    params = {}
    
    network = []
    for i in range(len(layer_sizes) - 1):
        n_in = layer_sizes[i]
        n_out = layer_sizes[i + 1]
        
        # Split key for weights and biases
        w_key, b_key = random.split(keys[i])
        
        # Xavier initialization for weights
        network.append({
            'w': random.normal(w_key, (n_in, n_out)) * jnp.sqrt(2.0 / n_in),
            'b': jnp.zeros(n_out)
        })
    
    params['network'] = network
    params['log_kappa'] = jnp.log(kappa)  # Learn log(kappa) to ensure positivity

    return params


def network(params, x):
    """
    Forward pass through the network.
    
    Args:
        params: List of layer parameters (from init_network_params)
        x: Input array, shape (batch_size, input_dim)
        
    Returns:
        Output array, shape (batch_size, output_dim)
    """
    # Process all hidden layers (all but last)
    

    for layer in params['network'][:-1]:
        # Linear transformation: x @ W + b
        x = jnp.dot(x, layer['w']) + layer['b']
        # Activation function
        x = jnp.tanh(x)
    
    # Output layer (no activation)
    final_layer = params['network'][-1]
    x = jnp.dot(x, final_layer['w']) + final_layer['b']
    
    return x


# Calculate Residual

def physics_residual_single(params, t_point, x_point):

    def u(t_val, x_val):
        tx_in = jnp.array([[t_val, x_val]])
        return network(params, tx_in)[0, 0]
    
    du_dt = grad(u, argnums=0)(t_point, x_point)

    d2u_dx2 = grad(grad(u, argnums = 1), argnums=1)(t_point, x_point)

    kappa_eff = normalize_kappa(jnp.exp(params['log_kappa']))  # Ensure positivity

    return du_dt / kappa_eff - d2u_dx2


# Vectorize to handle all physics points at once
# So vmap will call physics_residual_single 10000 times, once for each (t, x) pair, keeping params fixed.
physics_residual_batch = vmap(physics_residual_single, in_axes=(None, 0, 0))


# Initialize network
key = random.PRNGKey(123)
layer_sizes = [2, 64, 64, 64, 64, 1]  # 2 inputs (t, x), 1 output (u)
params = init_network_params(layer_sizes, key)

# Initialize optimizer
learning_rate = 1e-3
schedule = optax.piecewise_constant_schedule(init_value=learning_rate, boundaries_and_scales={60000: 0.1})
optimizer = optax.adam(learning_rate)
opt_state = optimizer.init(params)


@jit
def update_step(params, opt_state,
                t_bc, x_bc, u_bc, t_physics, x_physics, t_data, x_data, u_data):

    def loss_fn(params):
        
        # 1. Boundary Condition Loss
        tx_bc = jnp.concatenate([t_bc, x_bc], axis=1)
        u_pred_bc = network(params, tx_bc)
        bc_loss = jnp.mean((u_pred_bc - u_bc)**2)
        
        # 2. Physics Loss
        physics_residuals = physics_residual_batch(params, 
                                                t_physics.ravel(), # (10000,) not (10000, 1)
                                                x_physics.ravel()) # (10000,) not (10000, 1)
        physics_loss = jnp.mean(physics_residuals**2) # Physics residual is of 10000 points.

        # 3. Data Loss
        tx_data = jnp.concatenate([t_data, x_data], axis=1)
        u_pred_data = network(params, tx_data)
        data_loss = jnp.mean((u_pred_data - u_data)**2)
        
        return  bc_loss * 100 + physics_loss + data_loss * 50, (bc_loss, physics_loss, data_loss)
    
        # Compute loss and gradients
    (loss_val, individual_loss), grads = jax.value_and_grad(loss_fn, has_aux=True)(params)
    
    # Update parameters
    updates, new_opt_state = optimizer.update(grads, opt_state, params)
    new_params = optax.apply_updates(params, updates)
    
    return new_params, new_opt_state, loss_val, individual_loss


# Training parameters
num_iterations = 120000
save_every = 150  # Save every 150 iterations
print_every = 1000

# Storage for snapshots
snapshots = []
snapshot_iterations = []

# Prepare physics points (flatten for vmap)
t_phys_flat = t_physics.ravel()
x_phys_flat = x_physics.ravel()

# Training loop
losses = []
losses_bc = []
losses_phys = []
losses_data = []
for i in range(num_iterations):
    params, opt_state, loss, individual_loss = update_step(
        params, opt_state,
        t_bc, x_bc, u_bc,
        t_phys_flat, x_phys_flat,
        t_data, x_data, u_data
    )
    
    losses.append(loss)
    losses_bc.append(individual_loss[0])
    losses_phys.append(individual_loss[1])
    losses_data.append(individual_loss[2])


    # Save snapshot every 150 iterations
    if (i + 1) % save_every == 0:
        # Make a copy of params (important!)
        snapshots.append(copy.deepcopy(params))
        snapshot_iterations.append(i + 1)

    
    if (i + 1) % print_every == 0:
        print(f"Iteration {i+1}/{num_iterations}, Loss: {loss:.6f}")
        print(f"  BC Loss: {individual_loss[0]:.6f}, Physics Loss: {individual_loss[1]:.6f}, Data Loss: {individual_loss[2]:.6f}")
        print(f"  Current kappa: {jnp.exp(params['log_kappa']):.2e} m^2/s")
# Out:
# Iteration 1000/120000, Loss: 67.629303
#   BC Loss: 0.056815, Physics Loss: 61.643875, Data Loss: 0.006078
#   Current kappa: 1.01e-09 m^2/s
# Iteration 2000/120000, Loss: 28.629246
#   BC Loss: 0.056949, Physics Loss: 22.596516, Data Loss: 0.006757
#   Current kappa: 1.01e-09 m^2/s
# Iteration 3000/120000, Loss: 19.433134
#   BC Loss: 0.057039, Physics Loss: 13.375752, Data Loss: 0.007070
#   Current kappa: 1.01e-09 m^2/s
# Iteration 4000/120000, Loss: 13.939618
#   BC Loss: 0.056987, Physics Loss: 7.890009, Data Loss: 0.007017
#   Current kappa: 1.01e-09 m^2/s
# Iteration 5000/120000, Loss: 10.524575
#   BC Loss: 0.056845, Physics Loss: 4.514802, Data Loss: 0.006506
#   Current kappa: 1.01e-09 m^2/s
# Iteration 6000/120000, Loss: 15.932131
#   BC Loss: 0.056578, Physics Loss: 10.082780, Data Loss: 0.003831
#   Current kappa: 1.02e-09 m^2/s
# Iteration 7000/120000, Loss: 11.349566
#   BC Loss: 0.056843, Physics Loss: 5.605169, Data Loss: 0.001203
#   Current kappa: 1.03e-09 m^2/s
# Iteration 8000/120000, Loss: 6.655655
#   BC Loss: 0.057078, Physics Loss: 0.898358, Data Loss: 0.000990
#   Current kappa: 1.03e-09 m^2/s
# Iteration 9000/120000, Loss: 6.270891
#   BC Loss: 0.056431, Physics Loss: 0.574226, Data Loss: 0.001071
#   Current kappa: 1.03e-09 m^2/s
# Iteration 10000/120000, Loss: 6.028645
#   BC Loss: 0.056131, Physics Loss: 0.368697, Data Loss: 0.000937
#   Current kappa: 1.04e-09 m^2/s
# Iteration 11000/120000, Loss: 6.851622
#   BC Loss: 0.055714, Physics Loss: 1.231533, Data Loss: 0.000975
#   Current kappa: 1.04e-09 m^2/s
# Iteration 12000/120000, Loss: 5.772130
#   BC Loss: 0.055522, Physics Loss: 0.177202, Data Loss: 0.000854
#   Current kappa: 1.05e-09 m^2/s
# Iteration 13000/120000, Loss: 5.722266
#   BC Loss: 0.055388, Physics Loss: 0.144833, Data Loss: 0.000773
#   Current kappa: 1.05e-09 m^2/s
# Iteration 14000/120000, Loss: 5.870963
#   BC Loss: 0.055423, Physics Loss: 0.293689, Data Loss: 0.000700
#   Current kappa: 1.07e-09 m^2/s
# Iteration 15000/120000, Loss: 5.864872
#   BC Loss: 0.055283, Physics Loss: 0.305077, Data Loss: 0.000629
#   Current kappa: 1.07e-09 m^2/s
# Iteration 16000/120000, Loss: 7.408144
#   BC Loss: 0.055346, Physics Loss: 1.849290, Data Loss: 0.000484
#   Current kappa: 1.08e-09 m^2/s
# Iteration 17000/120000, Loss: 6.428611
#   BC Loss: 0.055252, Physics Loss: 0.879046, Data Loss: 0.000487
#   Current kappa: 1.09e-09 m^2/s
# Iteration 18000/120000, Loss: 9.295963
#   BC Loss: 0.055356, Physics Loss: 3.738384, Data Loss: 0.000439
#   Current kappa: 1.11e-09 m^2/s
# Iteration 19000/120000, Loss: 6.832075
#   BC Loss: 0.055157, Physics Loss: 1.294402, Data Loss: 0.000440
#   Current kappa: 1.12e-09 m^2/s
# Iteration 20000/120000, Loss: 5.574350
#   BC Loss: 0.055203, Physics Loss: 0.034086, Data Loss: 0.000399
#   Current kappa: 1.13e-09 m^2/s
# Iteration 21000/120000, Loss: 5.551566
#   BC Loss: 0.055229, Physics Loss: 0.008439, Data Loss: 0.000406
#   Current kappa: 1.17e-09 m^2/s
# Iteration 22000/120000, Loss: 5.543806
#   BC Loss: 0.055202, Physics Loss: 0.004969, Data Loss: 0.000372
#   Current kappa: 1.17e-09 m^2/s
# Iteration 23000/120000, Loss: 5.549586
#   BC Loss: 0.055193, Physics Loss: 0.011818, Data Loss: 0.000370
#   Current kappa: 1.19e-09 m^2/s
# Iteration 24000/120000, Loss: 5.635116
#   BC Loss: 0.055580, Physics Loss: 0.054320, Data Loss: 0.000455
#   Current kappa: 1.30e-09 m^2/s
# Iteration 25000/120000, Loss: 5.588357
#   BC Loss: 0.055551, Physics Loss: 0.010922, Data Loss: 0.000448
#   Current kappa: 1.30e-09 m^2/s
# Iteration 26000/120000, Loss: 5.579240
#   BC Loss: 0.055515, Physics Loss: 0.005578, Data Loss: 0.000443
#   Current kappa: 1.30e-09 m^2/s
# Iteration 27000/120000, Loss: 5.574361
#   BC Loss: 0.055480, Physics Loss: 0.004375, Data Loss: 0.000439
#   Current kappa: 1.30e-09 m^2/s
# Iteration 28000/120000, Loss: 5.570151
#   BC Loss: 0.055445, Physics Loss: 0.003828, Data Loss: 0.000435
#   Current kappa: 1.30e-09 m^2/s
# Iteration 29000/120000, Loss: 5.565612
#   BC Loss: 0.055404, Physics Loss: 0.003629, Data Loss: 0.000432
#   Current kappa: 1.30e-09 m^2/s
# Iteration 30000/120000, Loss: 5.560700
#   BC Loss: 0.055358, Physics Loss: 0.003626, Data Loss: 0.000426
#   Current kappa: 1.30e-09 m^2/s
# Iteration 31000/120000, Loss: 5.554358
#   BC Loss: 0.055299, Physics Loss: 0.003641, Data Loss: 0.000417
#   Current kappa: 1.30e-09 m^2/s
# Iteration 32000/120000, Loss: 5.548128
#   BC Loss: 0.055251, Physics Loss: 0.003135, Data Loss: 0.000398
#   Current kappa: 1.30e-09 m^2/s
# Iteration 33000/120000, Loss: 5.546731
#   BC Loss: 0.055242, Physics Loss: 0.003082, Data Loss: 0.000389
#   Current kappa: 1.31e-09 m^2/s
# Iteration 34000/120000, Loss: 5.544207
#   BC Loss: 0.055238, Physics Loss: 0.001009, Data Loss: 0.000388
#   Current kappa: 1.31e-09 m^2/s
# Iteration 35000/120000, Loss: 5.543250
#   BC Loss: 0.055234, Physics Loss: 0.000724, Data Loss: 0.000382
#   Current kappa: 1.31e-09 m^2/s
# Iteration 36000/120000, Loss: 5.542741
#   BC Loss: 0.055226, Physics Loss: 0.001459, Data Loss: 0.000374
#   Current kappa: 1.32e-09 m^2/s
# Iteration 37000/120000, Loss: 5.543104
#   BC Loss: 0.055213, Physics Loss: 0.002974, Data Loss: 0.000377
#   Current kappa: 1.33e-09 m^2/s
# Iteration 38000/120000, Loss: 5.546677
#   BC Loss: 0.055212, Physics Loss: 0.005477, Data Loss: 0.000400
#   Current kappa: 1.34e-09 m^2/s
# Iteration 39000/120000, Loss: 5.536992
#   BC Loss: 0.055175, Physics Loss: 0.001552, Data Loss: 0.000358
#   Current kappa: 1.36e-09 m^2/s
# Iteration 40000/120000, Loss: 5.534369
#   BC Loss: 0.055079, Physics Loss: 0.008523, Data Loss: 0.000358
#   Current kappa: 1.41e-09 m^2/s
# Iteration 41000/120000, Loss: 5.560004
#   BC Loss: 0.055372, Physics Loss: 0.001713, Data Loss: 0.000421
#   Current kappa: 1.56e-09 m^2/s
# Iteration 42000/120000, Loss: 5.531107
#   BC Loss: 0.055102, Physics Loss: 0.002044, Data Loss: 0.000377
#   Current kappa: 1.69e-09 m^2/s
# Iteration 43000/120000, Loss: 4.916219
#   BC Loss: 0.045702, Physics Loss: 0.325781, Data Loss: 0.000405
#   Current kappa: 1.84e-09 m^2/s
# Iteration 44000/120000, Loss: 4.677753
#   BC Loss: 0.045935, Physics Loss: 0.065932, Data Loss: 0.000367
#   Current kappa: 1.93e-09 m^2/s
# Iteration 45000/120000, Loss: 3.740968
#   BC Loss: 0.023696, Physics Loss: 1.352679, Data Loss: 0.000375
#   Current kappa: 1.99e-09 m^2/s
# Iteration 46000/120000, Loss: 5.888570
#   BC Loss: 0.013601, Physics Loss: 4.509376, Data Loss: 0.000381
#   Current kappa: 2.03e-09 m^2/s
# Iteration 47000/120000, Loss: 1.755894
#   BC Loss: 0.012961, Physics Loss: 0.441243, Data Loss: 0.000370
#   Current kappa: 2.06e-09 m^2/s
# Iteration 48000/120000, Loss: 1.335201
#   BC Loss: 0.008143, Physics Loss: 0.501316, Data Loss: 0.000391
#   Current kappa: 2.09e-09 m^2/s
# Iteration 49000/120000, Loss: 2.259547
#   BC Loss: 0.013468, Physics Loss: 0.886083, Data Loss: 0.000532
#   Current kappa: 2.11e-09 m^2/s
# Iteration 50000/120000, Loss: 1.910967
#   BC Loss: 0.006848, Physics Loss: 1.206059, Data Loss: 0.000402
#   Current kappa: 2.13e-09 m^2/s
# Iteration 51000/120000, Loss: 3.847627
#   BC Loss: 0.015270, Physics Loss: 2.288141, Data Loss: 0.000650
#   Current kappa: 2.15e-09 m^2/s
# Iteration 52000/120000, Loss: 1.413148
#   BC Loss: 0.005342, Physics Loss: 0.860279, Data Loss: 0.000374
#   Current kappa: 2.17e-09 m^2/s
# Iteration 53000/120000, Loss: 0.862384
#   BC Loss: 0.004863, Physics Loss: 0.348815, Data Loss: 0.000545
#   Current kappa: 2.19e-09 m^2/s
# Iteration 54000/120000, Loss: 1.284920
#   BC Loss: 0.003968, Physics Loss: 0.866055, Data Loss: 0.000441
#   Current kappa: 2.20e-09 m^2/s
# Iteration 55000/120000, Loss: 0.424420
#   BC Loss: 0.003560, Physics Loss: 0.049529, Data Loss: 0.000378
#   Current kappa: 2.22e-09 m^2/s
# Iteration 56000/120000, Loss: 0.469330
#   BC Loss: 0.003336, Physics Loss: 0.114480, Data Loss: 0.000426
#   Current kappa: 2.24e-09 m^2/s
# Iteration 57000/120000, Loss: 1.090543
#   BC Loss: 0.002860, Physics Loss: 0.785976, Data Loss: 0.000371
#   Current kappa: 2.25e-09 m^2/s
# Iteration 58000/120000, Loss: 0.412883
#   BC Loss: 0.002649, Physics Loss: 0.128001, Data Loss: 0.000400
#   Current kappa: 2.27e-09 m^2/s
# Iteration 59000/120000, Loss: 2.200413
#   BC Loss: 0.004782, Physics Loss: 1.700115, Data Loss: 0.000441
#   Current kappa: 2.29e-09 m^2/s
# Iteration 60000/120000, Loss: 0.365863
#   BC Loss: 0.002867, Physics Loss: 0.060707, Data Loss: 0.000369
#   Current kappa: 2.30e-09 m^2/s
# Iteration 61000/120000, Loss: 3.086667
#   BC Loss: 0.002008, Physics Loss: 2.866976, Data Loss: 0.000377
#   Current kappa: 2.32e-09 m^2/s
# Iteration 62000/120000, Loss: 0.456869
#   BC Loss: 0.001936, Physics Loss: 0.245045, Data Loss: 0.000364
#   Current kappa: 2.33e-09 m^2/s
# Iteration 63000/120000, Loss: 0.586851
#   BC Loss: 0.002278, Physics Loss: 0.339432, Data Loss: 0.000393
#   Current kappa: 2.35e-09 m^2/s
# Iteration 64000/120000, Loss: 0.301720
#   BC Loss: 0.001815, Physics Loss: 0.100955, Data Loss: 0.000385
#   Current kappa: 2.36e-09 m^2/s
# Iteration 65000/120000, Loss: 0.321647
#   BC Loss: 0.002030, Physics Loss: 0.100342, Data Loss: 0.000366
#   Current kappa: 2.38e-09 m^2/s
# Iteration 66000/120000, Loss: 0.358246
#   BC Loss: 0.001913, Physics Loss: 0.148755, Data Loss: 0.000365
#   Current kappa: 2.39e-09 m^2/s
# Iteration 67000/120000, Loss: 0.269194
#   BC Loss: 0.001747, Physics Loss: 0.075677, Data Loss: 0.000377
#   Current kappa: 2.41e-09 m^2/s
# Iteration 68000/120000, Loss: 0.355434
#   BC Loss: 0.002105, Physics Loss: 0.126606, Data Loss: 0.000367
#   Current kappa: 2.42e-09 m^2/s
# Iteration 69000/120000, Loss: 0.241552
#   BC Loss: 0.001693, Physics Loss: 0.054117, Data Loss: 0.000364
#   Current kappa: 2.43e-09 m^2/s
# Iteration 70000/120000, Loss: 0.436189
#   BC Loss: 0.001315, Physics Loss: 0.286187, Data Loss: 0.000370
#   Current kappa: 2.45e-09 m^2/s
# Iteration 71000/120000, Loss: 1.428997
#   BC Loss: 0.001184, Physics Loss: 1.291567, Data Loss: 0.000380
#   Current kappa: 2.46e-09 m^2/s
# Iteration 72000/120000, Loss: 0.525247
#   BC Loss: 0.002865, Physics Loss: 0.214417, Data Loss: 0.000486
#   Current kappa: 2.47e-09 m^2/s
# Iteration 73000/120000, Loss: 0.426737
#   BC Loss: 0.003444, Physics Loss: 0.062511, Data Loss: 0.000397
#   Current kappa: 2.49e-09 m^2/s
# Iteration 74000/120000, Loss: 0.413597
#   BC Loss: 0.001186, Physics Loss: 0.276790, Data Loss: 0.000364
#   Current kappa: 2.50e-09 m^2/s
# Iteration 75000/120000, Loss: 2.525355
#   BC Loss: 0.001025, Physics Loss: 2.404610, Data Loss: 0.000364
#   Current kappa: 2.51e-09 m^2/s
# Iteration 76000/120000, Loss: 0.581496
#   BC Loss: 0.001409, Physics Loss: 0.422342, Data Loss: 0.000366
#   Current kappa: 2.53e-09 m^2/s
# Iteration 77000/120000, Loss: 0.409132
#   BC Loss: 0.000974, Physics Loss: 0.293268, Data Loss: 0.000370
#   Current kappa: 2.54e-09 m^2/s
# Iteration 78000/120000, Loss: 1.338575
#   BC Loss: 0.003115, Physics Loss: 1.008939, Data Loss: 0.000363
#   Current kappa: 2.55e-09 m^2/s
# Iteration 79000/120000, Loss: 0.571630
#   BC Loss: 0.003175, Physics Loss: 0.233901, Data Loss: 0.000405
#   Current kappa: 2.57e-09 m^2/s
# Iteration 80000/120000, Loss: 1.235650
#   BC Loss: 0.001597, Physics Loss: 1.057216, Data Loss: 0.000375
#   Current kappa: 2.58e-09 m^2/s
# Iteration 81000/120000, Loss: 0.190997
#   BC Loss: 0.000885, Physics Loss: 0.084206, Data Loss: 0.000366
#   Current kappa: 2.59e-09 m^2/s
# Iteration 82000/120000, Loss: 0.141288
#   BC Loss: 0.001049, Physics Loss: 0.018104, Data Loss: 0.000366
#   Current kappa: 2.61e-09 m^2/s
# Iteration 83000/120000, Loss: 0.234298
#   BC Loss: 0.001572, Physics Loss: 0.058799, Data Loss: 0.000367
#   Current kappa: 2.62e-09 m^2/s
# Iteration 84000/120000, Loss: 0.190578
#   BC Loss: 0.001143, Physics Loss: 0.057971, Data Loss: 0.000366
#   Current kappa: 2.63e-09 m^2/s
# Iteration 85000/120000, Loss: 0.291175
#   BC Loss: 0.001026, Physics Loss: 0.170265, Data Loss: 0.000367
#   Current kappa: 2.65e-09 m^2/s
# Iteration 86000/120000, Loss: 0.482796
#   BC Loss: 0.001841, Physics Loss: 0.280363, Data Loss: 0.000367
#   Current kappa: 2.66e-09 m^2/s
# Iteration 87000/120000, Loss: 0.311621
#   BC Loss: 0.000891, Physics Loss: 0.204341, Data Loss: 0.000364
#   Current kappa: 2.67e-09 m^2/s
# Iteration 88000/120000, Loss: 0.312939
#   BC Loss: 0.000793, Physics Loss: 0.214817, Data Loss: 0.000377
#   Current kappa: 2.68e-09 m^2/s
# Iteration 89000/120000, Loss: 0.157550
#   BC Loss: 0.000974, Physics Loss: 0.041857, Data Loss: 0.000365
#   Current kappa: 2.70e-09 m^2/s
# Iteration 90000/120000, Loss: 0.353798
#   BC Loss: 0.000875, Physics Loss: 0.247942, Data Loss: 0.000368
#   Current kappa: 2.71e-09 m^2/s
# Iteration 91000/120000, Loss: 0.176103
#   BC Loss: 0.000716, Physics Loss: 0.086212, Data Loss: 0.000365
#   Current kappa: 2.72e-09 m^2/s
# Iteration 92000/120000, Loss: 0.220611
#   BC Loss: 0.000990, Physics Loss: 0.103199, Data Loss: 0.000369
#   Current kappa: 2.73e-09 m^2/s
# Iteration 93000/120000, Loss: 0.513118
#   BC Loss: 0.000667, Physics Loss: 0.428142, Data Loss: 0.000365
#   Current kappa: 2.75e-09 m^2/s
# Iteration 94000/120000, Loss: 0.204934
#   BC Loss: 0.000822, Physics Loss: 0.104338, Data Loss: 0.000368
#   Current kappa: 2.76e-09 m^2/s
# Iteration 95000/120000, Loss: 0.629405
#   BC Loss: 0.000727, Physics Loss: 0.538358, Data Loss: 0.000367
#   Current kappa: 2.77e-09 m^2/s
# Iteration 96000/120000, Loss: 0.140425
#   BC Loss: 0.000658, Physics Loss: 0.055923, Data Loss: 0.000374
#   Current kappa: 2.78e-09 m^2/s
# Iteration 97000/120000, Loss: 4.598053
#   BC Loss: 0.001012, Physics Loss: 4.477536, Data Loss: 0.000386
#   Current kappa: 2.80e-09 m^2/s
# Iteration 98000/120000, Loss: 0.114241
#   BC Loss: 0.000614, Physics Loss: 0.034361, Data Loss: 0.000370
#   Current kappa: 2.81e-09 m^2/s
# Iteration 99000/120000, Loss: 0.187024
#   BC Loss: 0.000732, Physics Loss: 0.094267, Data Loss: 0.000391
#   Current kappa: 2.82e-09 m^2/s
# Iteration 100000/120000, Loss: 0.158684
#   BC Loss: 0.000760, Physics Loss: 0.064368, Data Loss: 0.000365
#   Current kappa: 2.83e-09 m^2/s
# Iteration 101000/120000, Loss: 0.150230
#   BC Loss: 0.000787, Physics Loss: 0.052824, Data Loss: 0.000375
#   Current kappa: 2.85e-09 m^2/s
# Iteration 102000/120000, Loss: 4.612955
#   BC Loss: 0.000641, Physics Loss: 4.530182, Data Loss: 0.000373
#   Current kappa: 2.86e-09 m^2/s
# Iteration 103000/120000, Loss: 0.164761
#   BC Loss: 0.000623, Physics Loss: 0.083962, Data Loss: 0.000370
#   Current kappa: 2.87e-09 m^2/s
# Iteration 104000/120000, Loss: 0.213600
#   BC Loss: 0.000837, Physics Loss: 0.111321, Data Loss: 0.000371
#   Current kappa: 2.88e-09 m^2/s
# Iteration 105000/120000, Loss: 0.602525
#   BC Loss: 0.000650, Physics Loss: 0.519097, Data Loss: 0.000368
#   Current kappa: 2.90e-09 m^2/s
# Iteration 106000/120000, Loss: 0.362005
#   BC Loss: 0.001186, Physics Loss: 0.224151, Data Loss: 0.000384
#   Current kappa: 2.91e-09 m^2/s
# Iteration 107000/120000, Loss: 0.283000
#   BC Loss: 0.001312, Physics Loss: 0.132865, Data Loss: 0.000378
#   Current kappa: 2.92e-09 m^2/s
# Iteration 108000/120000, Loss: 0.102098
#   BC Loss: 0.000549, Physics Loss: 0.028896, Data Loss: 0.000366
#   Current kappa: 2.93e-09 m^2/s
# Iteration 109000/120000, Loss: 0.395205
#   BC Loss: 0.001898, Physics Loss: 0.186456, Data Loss: 0.000378
#   Current kappa: 2.95e-09 m^2/s
# Iteration 110000/120000, Loss: 0.414528
#   BC Loss: 0.000630, Physics Loss: 0.333291, Data Loss: 0.000365
#   Current kappa: 2.96e-09 m^2/s
# Iteration 111000/120000, Loss: 0.169519
#   BC Loss: 0.000525, Physics Loss: 0.098503, Data Loss: 0.000370
#   Current kappa: 2.97e-09 m^2/s
# Iteration 112000/120000, Loss: 0.165529
#   BC Loss: 0.000848, Physics Loss: 0.062447, Data Loss: 0.000366
#   Current kappa: 2.98e-09 m^2/s
# Iteration 113000/120000, Loss: 0.309561
#   BC Loss: 0.001300, Physics Loss: 0.161261, Data Loss: 0.000366
#   Current kappa: 3.00e-09 m^2/s
# Iteration 114000/120000, Loss: 0.169408
#   BC Loss: 0.000590, Physics Loss: 0.092124, Data Loss: 0.000365
#   Current kappa: 3.01e-09 m^2/s
# Iteration 115000/120000, Loss: 0.338830
#   BC Loss: 0.000618, Physics Loss: 0.258632, Data Loss: 0.000368
#   Current kappa: 3.02e-09 m^2/s
# Iteration 116000/120000, Loss: 0.140428
#   BC Loss: 0.000573, Physics Loss: 0.064839, Data Loss: 0.000365
#   Current kappa: 3.03e-09 m^2/s
# Iteration 117000/120000, Loss: 0.215407
#   BC Loss: 0.000641, Physics Loss: 0.133007, Data Loss: 0.000365
#   Current kappa: 3.05e-09 m^2/s
# Iteration 118000/120000, Loss: 0.194322
#   BC Loss: 0.000990, Physics Loss: 0.076885, Data Loss: 0.000369
#   Current kappa: 3.06e-09 m^2/s
# Iteration 119000/120000, Loss: 0.172803
#   BC Loss: 0.000495, Physics Loss: 0.104509, Data Loss: 0.000377
#   Current kappa: 3.07e-09 m^2/s
# Iteration 120000/120000, Loss: 0.148806
#   BC Loss: 0.000566, Physics Loss: 0.073962, Data Loss: 0.000365
#   Current kappa: 3.08e-09 m^2/s

# %% [markdown]
# ## Compare PINN with Data

# %%
# ============================================================
# Plot: Network prediction vs TEM-A data at mole depth -------
# ============================================================

# Create a dense time array at the mole depth (normalised)
t_plot = jnp.linspace(0, 1, 500).reshape(-1, 1)  # normalised time [0,1]
x_plot = jnp.ones((500, 1)) * normalize_x(mole_depth)  # normalised mole depth

# Network prediction (normalised)
tx_plot = jnp.concatenate([t_plot, x_plot], axis=1)
u_pred_norm = network(params, tx_plot)

# Convert back to physical units
t_plot_hours = np.array(t_plot.ravel()) * 24  # back to LTST hours
u_pred_K = np.array(unnormalize_u(u_pred_norm.ravel()))  # back to Kelvin

# Also convert mole data back to hours for comparison
t_mole_hours = np.array(ltst_mole) * 24 / sol_seconds * (24/24)
# Actually ltst_mole is already in seconds (converted earlier), so:
t_mole_hours = np.array(ltst_mole) / sol_seconds * 24  # seconds -> LTST hours
u_mole_K = np.array(temp_mole)  # already in Kelvin

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# Left: overlay prediction and data
ax1 = axes[0]
ax1.plot(t_mole_hours, u_mole_K, 'r.', markersize=1, alpha=0.3, label='TEM-A data')
ax1.plot(t_plot_hours, u_pred_K, 'b-', linewidth=2, label='PINN prediction')
ax1.set_xlabel('Local True Solar Time [hours]')
ax1.set_ylabel('Temperature [K]')
ax1.set_title('Mole Depth (9.4 cm): PINN vs Data')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Right: error (prediction - data) over time
# Interpolate prediction to data time points for direct comparison
u_pred_at_data = np.interp(t_mole_hours, t_plot_hours, u_pred_K)
error = u_pred_at_data - u_mole_K

ax2 = axes[1]
ax2.plot(t_mole_hours, error, 'k.', markersize=1, alpha=0.3)
ax2.axhline(y=0, color='r', linestyle='--', alpha=0.5)
ax2.set_xlabel('Local True Solar Time [hours]')
ax2.set_ylabel('Error [K]')
ax2.set_title(f'Prediction Error (RMSE = {np.sqrt(np.mean(error**2)):.2f} K)')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Does the PINN follow the Physics?

# %%
# Temperature vs Depth at four times of day
fig, axes = plt.subplots(1, 4, figsize=(20, 5), sharey=True)

hours_to_plot = [3, 9, 15, 21]
depths = jnp.linspace(0, depth, 200)  # 0 to 0.4 m

for idx, hour in enumerate(hours_to_plot):
    t_sec = hour * sol_seconds / 24
    t_norm = normalize_t(t_sec)
    x_norm = normalize_x(depths)
    
    # Build input array
    t_input = jnp.ones_like(x_norm) * t_norm
    tx_input = jnp.stack([t_input, x_norm], axis=-1)
    
    # Predict
    u_pred_norm = network(params, tx_input)
    u_pred = unnormalize_u(u_pred_norm.ravel())
    
    axes[idx].plot(depths * 100, u_pred, 'b-', linewidth=2)  # depth in cm
    axes[idx].set_title(f'LTST = {hour}:00')
    axes[idx].set_xlabel('Depth [cm]')
    axes[idx].axhline(y=avg_bottom_temp, color='gray', linestyle='--', alpha=0.5, label='Bottom BC')
    
axes[0].set_ylabel('Temperature [K]')
plt.suptitle('Temperature vs Depth at Different Times of Sol', fontsize=14)
plt.tight_layout()
plt.show()


# 3D surface plot: T(t, x)
from mpl_toolkits.mplot3d import Axes3D

n_t, n_x = 200, 200
t_grid = jnp.linspace(0, 1, n_t)  # already normalized
x_grid = jnp.linspace(0, 1, n_x)  # already normalized

T_mesh, X_mesh = jnp.meshgrid(t_grid, x_grid)
tx_flat = jnp.stack([T_mesh.ravel(), X_mesh.ravel()], axis=-1)

u_pred_flat = network(params, tx_flat)
u_pred_grid = unnormalize_u(u_pred_flat.reshape(n_x, n_t))

# Convert axes back to physical units for plotting
t_hours = np.linspace(0, 24, n_t)
x_cm = np.linspace(0, depth * 100, n_x)
T_plot, X_plot = np.meshgrid(t_hours, x_cm)

fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(T_plot, X_plot, np.array(u_pred_grid), cmap='inferno', alpha=0.9)
ax.set_xlabel('Local True Solar Time [hours]')
ax.set_ylabel('Depth [cm]')
ax.set_zlabel('Temperature [K]')
ax.set_title('PINN Predicted Temperature Field T(t, x)')
fig.colorbar(surf, shrink=0.5, label='Temperature [K]')
plt.tight_layout()
plt.show()


# PINN vs RAD at surface (x=0)
t_surf_norm = normalize_t(jnp.array(ltst_surf))
x_surf_norm = jnp.zeros_like(t_surf_norm)
tx_surf = jnp.stack([t_surf_norm, x_surf_norm], axis=-1)

u_pred_surf = unnormalize_u(network(params, tx_surf).ravel())

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ltst_hours_surf = [t * 24 / sol_seconds for t in ltst_surf]

axes[0].scatter(ltst_hours_surf, temp_surf, s=1, c='red', alpha=0.5, label='RAD data')
axes[0].plot(ltst_hours_surf, np.array(u_pred_surf), 'b-', linewidth=2, label='PINN prediction')
axes[0].set_xlabel('Local True Solar Time [hours]')
axes[0].set_ylabel('Temperature [K]')
axes[0].set_title('Surface (x=0): PINN vs RAD')
axes[0].legend()

# Error at surface
error_surf = np.array(u_pred_surf) - np.array(temp_surf)
axes[1].plot(ltst_hours_surf, error_surf, 'k-', linewidth=0.5)
axes[1].axhline(y=0, color='r', linestyle='--', alpha=0.5)
axes[1].set_xlabel('Local True Solar Time [hours]')
axes[1].set_ylabel('Error [K]')
rmse_surf = np.sqrt(np.mean(error_surf**2))
axes[1].set_title(f'Surface Prediction Error (RMSE = {rmse_surf:.2f} K)')

plt.tight_layout()
plt.show()
